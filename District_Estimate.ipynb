# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import json


url='https://mogi.vn/gia-nha-dat-quan-3-qd368'


# Đường dẫn đến trình điều khiển ChromeDriver
webdriver_service = Service('path/to/chromedriver')

# Khởi tạo trình điều khiển Chrome
driver = webdriver.Chrome(service=webdriver_service)

# Mở trang web
driver.get(url)

driver.implicitly_wait(10)

html_content = driver.page_source

try:
    soup = BeautifulSoup(html_content, 'html.parser')
    type_elements = [i.text for i in soup.find_all('div', class_='mt-street')]
    price_elements = [i.text for i in soup.find_all('div', class_='mt-vol text-right number')]
except:
    print('Cannot connect to website:' + url)

driver.quit()

type = []
price = []
result = []
if type_elements is not None:
    
    for i in range(len(price_elements)):
        price.append(price_elements[i].replace('\n', ' ').strip())
            
    
    for i in range(len(type_elements)):
        type.append(type_elements[i].replace('\n', ' ').replace('\t', ' ').strip())
    
    type = [x for x in type if x not in ["Loại", "Đường"]]
    
    for i in range(len(type)):
        item = {
            'Type Property': type[i],
            'Value Property': price[i]
        }
        result.append(item)

    with open('District3_Estimate.json', 'w', encoding='utf-8') as f:
        json.dump(result, f, ensure_ascii=False)
else:
    print('Cannot connected to website')

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import json


url='https://mogi.vn/gia-nha-dat-quan-4-qd369'


# Đường dẫn đến trình điều khiển ChromeDriver
webdriver_service = Service('path/to/chromedriver')

# Khởi tạo trình điều khiển Chrome
driver = webdriver.Chrome(service=webdriver_service)

# Mở trang web
driver.get(url)

driver.implicitly_wait(10)

html_content = driver.page_source

try:
    soup = BeautifulSoup(html_content, 'html.parser')
    type_elements = [i.text for i in soup.find_all('div', class_='mt-street')]
    price_elements = [i.text for i in soup.find_all('div', class_='mt-vol text-right number')]
except:
    print('Cannot connect to website:' + url)

driver.quit()

type = []
price = []
result = []
if type_elements is not None:
    
    for i in range(len(price_elements)):
        price.append(price_elements[i].replace('\n', ' ').strip())
            
    
    for i in range(len(type_elements)):
        type.append(type_elements[i].replace('\n', ' ').replace('\t', ' ').strip())
    
    type = [x for x in type if x not in ["Loại", "Đường"]]
    
    for i in range(len(type)):
        item = {
            'Type Property': type[i],
            'Value Property': price[i]
        }
        result.append(item)

    with open('District4_Estimate.json', 'w', encoding='utf-8') as f:
        json.dump(result, f, ensure_ascii=False)
else:
    print('Cannot connected to website')

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import json


url='https://mogi.vn/gia-nha-dat-quan-5-qd370'


# Đường dẫn đến trình điều khiển ChromeDriver
webdriver_service = Service('path/to/chromedriver')

# Khởi tạo trình điều khiển Chrome
driver = webdriver.Chrome(service=webdriver_service)

# Mở trang web
driver.get(url)

driver.implicitly_wait(10)

html_content = driver.page_source

try:
    soup = BeautifulSoup(html_content, 'html.parser')
    type_elements = [i.text for i in soup.find_all('div', class_='mt-street')]
    price_elements = [i.text for i in soup.find_all('div', class_='mt-vol text-right number')]
except:
    print('Cannot connect to website:' + url)

driver.quit()

type = []
price = []
result = []
if type_elements is not None:
    
    for i in range(len(price_elements)):
        price.append(price_elements[i].replace('\n', ' ').strip())
            
    
    for i in range(len(type_elements)):
        type.append(type_elements[i].replace('\n', ' ').replace('\t', ' ').strip())
    
    type = [x for x in type if x not in ["Loại", "Đường"]]
    
    for i in range(len(type)):
        item = {
            'Type Property': type[i],
            'Value Property': price[i]
        }
        result.append(item)

    with open('District5_Estimate.json', 'w', encoding='utf-8') as f:
        json.dump(result, f, ensure_ascii=False)
else:
    print('Cannot connected to website')

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import json


url='https://mogi.vn/gia-nha-dat-quan-6-qd371'


# Đường dẫn đến trình điều khiển ChromeDriver
webdriver_service = Service('path/to/chromedriver')

# Khởi tạo trình điều khiển Chrome
driver = webdriver.Chrome(service=webdriver_service)

# Mở trang web
driver.get(url)

driver.implicitly_wait(10)

html_content = driver.page_source

try:
    soup = BeautifulSoup(html_content, 'html.parser')
    type_elements = [i.text for i in soup.find_all('div', class_='mt-street')]
    price_elements = [i.text for i in soup.find_all('div', class_='mt-vol text-right number')]
except:
    print('Cannot connect to website:' + url)

driver.quit()

type = []
price = []
result = []
if type_elements is not None:
    
    for i in range(len(price_elements)):
        price.append(price_elements[i].replace('\n', ' ').strip())
            
    
    for i in range(len(type_elements)):
        type.append(type_elements[i].replace('\n', ' ').replace('\t', ' ').strip())
    
    type = [x for x in type if x not in ["Loại", "Đường"]]
    
    for i in range(len(type)):
        item = {
            'Type Property': type[i],
            'Value Property': price[i]
        }
        result.append(item)

    with open('District6_Estimate.json', 'w', encoding='utf-8') as f:
        json.dump(result, f, ensure_ascii=False)
else:
    print('Cannot connected to website')

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import json


url='https://mogi.vn/gia-nha-dat-quan-7-qd372'


# Đường dẫn đến trình điều khiển ChromeDriver
webdriver_service = Service('path/to/chromedriver')

# Khởi tạo trình điều khiển Chrome
driver = webdriver.Chrome(service=webdriver_service)

# Mở trang web
driver.get(url)

driver.implicitly_wait(10)

html_content = driver.page_source

try:
    soup = BeautifulSoup(html_content, 'html.parser')
    type_elements = [i.text for i in soup.find_all('div', class_='mt-street')]
    price_elements = [i.text for i in soup.find_all('div', class_='mt-vol text-right number')]
except:
    print('Cannot connect to website:' + url)

driver.quit()

type = []
price = []
result = []
if type_elements is not None:
    
    for i in range(len(price_elements)):
        price.append(price_elements[i].replace('\n', ' ').strip())
            
    
    for i in range(len(type_elements)):
        type.append(type_elements[i].replace('\n', ' ').replace('\t', ' ').strip())
    
    type = [x for x in type if x not in ["Loại", "Đường"]]
    
    for i in range(len(type)):
        item = {
            'Type Property': type[i],
            'Value Property': price[i]
        }
        result.append(item)

    with open('District7_Estimate.json', 'w', encoding='utf-8') as f:
        json.dump(result, f, ensure_ascii=False)
else:
    print('Cannot connected to website')

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import json


url='https://mogi.vn/gia-nha-dat-quan-8-qd373'


# Đường dẫn đến trình điều khiển ChromeDriver
webdriver_service = Service('path/to/chromedriver')

# Khởi tạo trình điều khiển Chrome
driver = webdriver.Chrome(service=webdriver_service)

# Mở trang web
driver.get(url)

driver.implicitly_wait(10)

html_content = driver.page_source

try:
    soup = BeautifulSoup(html_content, 'html.parser')
    type_elements = [i.text for i in soup.find_all('div', class_='mt-street')]
    price_elements = [i.text for i in soup.find_all('div', class_='mt-vol text-right number')]
except:
    print('Cannot connect to website:' + url)

driver.quit()

type = []
price = []
result = []
if type_elements is not None:
    
    for i in range(len(price_elements)):
        price.append(price_elements[i].replace('\n', ' ').strip())
            
    
    for i in range(len(type_elements)):
        type.append(type_elements[i].replace('\n', ' ').replace('\t', ' ').strip())
    
    type = [x for x in type if x not in ["Loại", "Đường"]]
    
    for i in range(len(type)):
        item = {
            'Type Property': type[i],
            'Value Property': price[i]
        }
        result.append(item)

    with open('District8_Estimate.json', 'w', encoding='utf-8') as f:
        json.dump(result, f, ensure_ascii=False)
else:
    print('Cannot connected to website')

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import json


url='https://mogi.vn/gia-nha-dat-quan-9-qd374'


# Đường dẫn đến trình điều khiển ChromeDriver
webdriver_service = Service('path/to/chromedriver')

# Khởi tạo trình điều khiển Chrome
driver = webdriver.Chrome(service=webdriver_service)

# Mở trang web
driver.get(url)

driver.implicitly_wait(10)

html_content = driver.page_source

try:
    soup = BeautifulSoup(html_content, 'html.parser')
    type_elements = [i.text for i in soup.find_all('div', class_='mt-street')]
    price_elements = [i.text for i in soup.find_all('div', class_='mt-vol text-right number')]
except:
    print('Cannot connect to website:' + url)

driver.quit()

type = []
price = []
result = []
if type_elements is not None:
    
    for i in range(len(price_elements)):
        price.append(price_elements[i].replace('\n', ' ').strip())
            
    
    for i in range(len(type_elements)):
        type.append(type_elements[i].replace('\n', ' ').replace('\t', ' ').strip())
    
    type = [x for x in type if x not in ["Loại", "Đường"]]
    
    for i in range(len(type)):
        item = {
            'Type Property': type[i],
            'Value Property': price[i]
        }
        result.append(item)

    with open('District9_Estimate.json', 'w', encoding='utf-8') as f:
        json.dump(result, f, ensure_ascii=False)
else:
    print('Cannot connected to website')

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import json


url='https://mogi.vn/gia-nha-dat-quan-10-qd364'


# Đường dẫn đến trình điều khiển ChromeDriver
webdriver_service = Service('path/to/chromedriver')

# Khởi tạo trình điều khiển Chrome
driver = webdriver.Chrome(service=webdriver_service)

# Mở trang web
driver.get(url)

driver.implicitly_wait(10)

html_content = driver.page_source

try:
    soup = BeautifulSoup(html_content, 'html.parser')
    type_elements = [i.text for i in soup.find_all('div', class_='mt-street')]
    price_elements = [i.text for i in soup.find_all('div', class_='mt-vol text-right number')]
except:
    print('Cannot connect to website:' + url)

driver.quit()

type = []
price = []
result = []
if type_elements is not None:
    
    for i in range(len(price_elements)):
        price.append(price_elements[i].replace('\n', ' ').strip())
            
    
    for i in range(len(type_elements)):
        type.append(type_elements[i].replace('\n', ' ').replace('\t', ' ').strip())
    
    type = [x for x in type if x not in ["Loại", "Đường"]]
    
    for i in range(len(type)):
        item = {
            'Type Property': type[i],
            'Value Property': price[i]
        }
        result.append(item)

    with open('District10_Estimate.json', 'w', encoding='utf-8') as f:
        json.dump(result, f, ensure_ascii=False)
else:
    print('Cannot connected to website')

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import json


url='https://mogi.vn/gia-nha-dat-quan-11-qd365'


# Đường dẫn đến trình điều khiển ChromeDriver
webdriver_service = Service('path/to/chromedriver')

# Khởi tạo trình điều khiển Chrome
driver = webdriver.Chrome(service=webdriver_service)

# Mở trang web
driver.get(url)

driver.implicitly_wait(10)

html_content = driver.page_source

try:
    soup = BeautifulSoup(html_content, 'html.parser')
    type_elements = [i.text for i in soup.find_all('div', class_='mt-street')]
    price_elements = [i.text for i in soup.find_all('div', class_='mt-vol text-right number')]
except:
    print('Cannot connect to website:' + url)

driver.quit()

type = []
price = []
result = []
if type_elements is not None:
    
    for i in range(len(price_elements)):
        price.append(price_elements[i].replace('\n', ' ').strip())
            
    
    for i in range(len(type_elements)):
        type.append(type_elements[i].replace('\n', ' ').replace('\t', ' ').strip())
    
    type = [x for x in type if x not in ["Loại", "Đường"]]
    
    for i in range(len(type)):
        item = {
            'Type Property': type[i],
            'Value Property': price[i]
        }
        result.append(item)

    with open('District11_Estimate.json', 'w', encoding='utf-8') as f:
        json.dump(result, f, ensure_ascii=False)
else:
    print('Cannot connected to website')

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import json


url='https://mogi.vn/gia-nha-dat-quan-12-qd366'


# Đường dẫn đến trình điều khiển ChromeDriver
webdriver_service = Service('path/to/chromedriver')

# Khởi tạo trình điều khiển Chrome
driver = webdriver.Chrome(service=webdriver_service)

# Mở trang web
driver.get(url)

driver.implicitly_wait(10)

html_content = driver.page_source

try:
    soup = BeautifulSoup(html_content, 'html.parser')
    type_elements = [i.text for i in soup.find_all('div', class_='mt-street')]
    price_elements = [i.text for i in soup.find_all('div', class_='mt-vol text-right number')]
except:
    print('Cannot connect to website:' + url)

driver.quit()

type = []
price = []
result = []
if type_elements is not None:
    
    for i in range(len(price_elements)):
        price.append(price_elements[i].replace('\n', ' ').strip())
            
    
    for i in range(len(type_elements)):
        type.append(type_elements[i].replace('\n', ' ').replace('\t', ' ').strip())
    
    type = [x for x in type if x not in ["Loại", "Đường"]]
    
    for i in range(len(type)):
        item = {
            'Type Property': type[i],
            'Value Property': price[i]
        }
        result.append(item)

    with open('District12_Estimate.json', 'w', encoding='utf-8') as f:
        json.dump(result, f, ensure_ascii=False)
else:
    print('Cannot connected to website')

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import json


url='https://mogi.vn/gia-nha-dat-quan-binh-tan-qd375'


# Đường dẫn đến trình điều khiển ChromeDriver
webdriver_service = Service('path/to/chromedriver')

# Khởi tạo trình điều khiển Chrome
driver = webdriver.Chrome(service=webdriver_service)

# Mở trang web
driver.get(url)

driver.implicitly_wait(10)

html_content = driver.page_source

try:
    soup = BeautifulSoup(html_content, 'html.parser')
    type_elements = [i.text for i in soup.find_all('div', class_='mt-street')]
    price_elements = [i.text for i in soup.find_all('div', class_='mt-vol text-right number')]
except:
    print('Cannot connect to website:' + url)

driver.quit()

type = []
price = []
result = []
if type_elements is not None:
    
    for i in range(len(price_elements)):
        price.append(price_elements[i].replace('\n', ' ').strip())
            
    
    for i in range(len(type_elements)):
        type.append(type_elements[i].replace('\n', ' ').replace('\t', ' ').strip())
    
    type = [x for x in type if x not in ["Loại", "Đường"]]
    
    for i in range(len(type)):
        item = {
            'Type Property': type[i],
            'Value Property': price[i]
        }
        result.append(item)

    with open('DistrictBinhTan_Estimate.json', 'w', encoding='utf-8') as f:
        json.dump(result, f, ensure_ascii=False)
else:
    print('Cannot connected to website')

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import json


url='https://mogi.vn/gia-nha-dat-quan-binh-thanh-qd376'


# Đường dẫn đến trình điều khiển ChromeDriver
webdriver_service = Service('path/to/chromedriver')

# Khởi tạo trình điều khiển Chrome
driver = webdriver.Chrome(service=webdriver_service)

# Mở trang web
driver.get(url)

driver.implicitly_wait(10)

html_content = driver.page_source

try:
    soup = BeautifulSoup(html_content, 'html.parser')
    type_elements = [i.text for i in soup.find_all('div', class_='mt-street')]
    price_elements = [i.text for i in soup.find_all('div', class_='mt-vol text-right number')]
except:
    print('Cannot connect to website:' + url)

driver.quit()

type = []
price = []
result = []
if type_elements is not None:
    
    for i in range(len(price_elements)):
        price.append(price_elements[i].replace('\n', ' ').strip())
            
    
    for i in range(len(type_elements)):
        type.append(type_elements[i].replace('\n', ' ').replace('\t', ' ').strip())
    
    type = [x for x in type if x not in ["Loại", "Đường"]]
    
    for i in range(len(type)):
        item = {
            'Type Property': type[i],
            'Value Property': price[i]
        }
        result.append(item)

    with open('DistrictBinhThanh_Estimate.json', 'w', encoding='utf-8') as f:
        json.dump(result, f, ensure_ascii=False)
else:
    print('Cannot connected to website')

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import json


url='https://mogi.vn/gia-nha-dat-quan-go-vap-qd377'


# Đường dẫn đến trình điều khiển ChromeDriver
webdriver_service = Service('path/to/chromedriver')

# Khởi tạo trình điều khiển Chrome
driver = webdriver.Chrome(service=webdriver_service)

# Mở trang web
driver.get(url)

driver.implicitly_wait(10)

html_content = driver.page_source

try:
    soup = BeautifulSoup(html_content, 'html.parser')
    type_elements = [i.text for i in soup.find_all('div', class_='mt-street')]
    price_elements = [i.text for i in soup.find_all('div', class_='mt-vol text-right number')]
except:
    print('Cannot connect to website:' + url)

driver.quit()

type = []
price = []
result = []
if type_elements is not None:
    
    for i in range(len(price_elements)):
        price.append(price_elements[i].replace('\n', ' ').strip())
            
    
    for i in range(len(type_elements)):
        type.append(type_elements[i].replace('\n', ' ').replace('\t', ' ').strip())
    
    type = [x for x in type if x not in ["Loại", "Đường"]]
    
    for i in range(len(type)):
        item = {
            'Type Property': type[i],
            'Value Property': price[i]
        }
        result.append(item)

    with open('DistrictGoVap_Estimate.json', 'w', encoding='utf-8') as f:
        json.dump(result, f, ensure_ascii=False)
else:
    print('Cannot connected to website')

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import json


url='https://mogi.vn/gia-nha-dat-quan-phu-nhuan-qd378'


# Đường dẫn đến trình điều khiển ChromeDriver
webdriver_service = Service('path/to/chromedriver')

# Khởi tạo trình điều khiển Chrome
driver = webdriver.Chrome(service=webdriver_service)

# Mở trang web
driver.get(url)

driver.implicitly_wait(10)

html_content = driver.page_source

try:
    soup = BeautifulSoup(html_content, 'html.parser')
    type_elements = [i.text for i in soup.find_all('div', class_='mt-street')]
    price_elements = [i.text for i in soup.find_all('div', class_='mt-vol text-right number')]
except:
    print('Cannot connect to website:' + url)

driver.quit()

type = []
price = []
result = []
if type_elements is not None:
    
    for i in range(len(price_elements)):
        price.append(price_elements[i].replace('\n', ' ').strip())
            
    
    for i in range(len(type_elements)):
        type.append(type_elements[i].replace('\n', ' ').replace('\t', ' ').strip())
    
    type = [x for x in type if x not in ["Loại", "Đường"]]
    
    for i in range(len(type)):
        item = {
            'Type Property': type[i],
            'Value Property': price[i]
        }
        result.append(item)

    with open('DistrictPhuNhuan_Estimate.json', 'w', encoding='utf-8') as f:
        json.dump(result, f, ensure_ascii=False)
else:
    print('Cannot connected to website')

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import json


url='https://mogi.vn/gia-nha-dat-quan-tan-binh-qd379'


# Đường dẫn đến trình điều khiển ChromeDriver
webdriver_service = Service('path/to/chromedriver')

# Khởi tạo trình điều khiển Chrome
driver = webdriver.Chrome(service=webdriver_service)

# Mở trang web
driver.get(url)

driver.implicitly_wait(10)

html_content = driver.page_source

try:
    soup = BeautifulSoup(html_content, 'html.parser')
    type_elements = [i.text for i in soup.find_all('div', class_='mt-street')]
    price_elements = [i.text for i in soup.find_all('div', class_='mt-vol text-right number')]
except:
    print('Cannot connect to website:' + url)

driver.quit()

type = []
price = []
result = []
if type_elements is not None:
    
    for i in range(len(price_elements)):
        price.append(price_elements[i].replace('\n', ' ').strip())
            
    
    for i in range(len(type_elements)):
        type.append(type_elements[i].replace('\n', ' ').replace('\t', ' ').strip())
    
    type = [x for x in type if x not in ["Loại", "Đường"]]
    
    for i in range(len(type)):
        item = {
            'Type Property': type[i],
            'Value Property': price[i]
        }
        result.append(item)

    with open('DistrictTanBinh_Estimate.json', 'w', encoding='utf-8') as f:
        json.dump(result, f, ensure_ascii=False)
else:
    print('Cannot connected to website')

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import json


url='https://mogi.vn/gia-nha-dat-quan-tan-phu-qd380'


# Đường dẫn đến trình điều khiển ChromeDriver
webdriver_service = Service('path/to/chromedriver')

# Khởi tạo trình điều khiển Chrome
driver = webdriver.Chrome(service=webdriver_service)

# Mở trang web
driver.get(url)

driver.implicitly_wait(10)

html_content = driver.page_source

try:
    soup = BeautifulSoup(html_content, 'html.parser')
    type_elements = [i.text for i in soup.find_all('div', class_='mt-street')]
    price_elements = [i.text for i in soup.find_all('div', class_='mt-vol text-right number')]
except:
    print('Cannot connect to website:' + url)

driver.quit()

type = []
price = []
result = []
if type_elements is not None:
    
    for i in range(len(price_elements)):
        price.append(price_elements[i].replace('\n', ' ').strip())
            
    
    for i in range(len(type_elements)):
        type.append(type_elements[i].replace('\n', ' ').replace('\t', ' ').strip())
    
    type = [x for x in type if x not in ["Loại", "Đường"]]
    
    for i in range(len(type)):
        item = {
            'Type Property': type[i],
            'Value Property': price[i]
        }
        result.append(item)

    with open('DistrictTanPhu_Estimate.json', 'w', encoding='utf-8') as f:
        json.dump(result, f, ensure_ascii=False)
else:
    print('Cannot connected to website')

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import json


url='https://mogi.vn/gia-nha-dat-quan-thu-duc-qd381'


# Đường dẫn đến trình điều khiển ChromeDriver
webdriver_service = Service('path/to/chromedriver')

# Khởi tạo trình điều khiển Chrome
driver = webdriver.Chrome(service=webdriver_service)

# Mở trang web
driver.get(url)

driver.implicitly_wait(10)

html_content = driver.page_source

try:
    soup = BeautifulSoup(html_content, 'html.parser')
    type_elements = [i.text for i in soup.find_all('div', class_='mt-street')]
    price_elements = [i.text for i in soup.find_all('div', class_='mt-vol text-right number')]
except:
    print('Cannot connect to website:' + url)

driver.quit()

type = []
price = []
result = []
if type_elements is not None:
    
    for i in range(len(price_elements)):
        price.append(price_elements[i].replace('\n', ' ').strip())
            
    
    for i in range(len(type_elements)):
        type.append(type_elements[i].replace('\n', ' ').replace('\t', ' ').strip())
    
    type = [x for x in type if x not in ["Loại", "Đường"]]
    
    for i in range(len(type)):
        item = {
            'Type Property': type[i],
            'Value Property': price[i]
        }
        result.append(item)

    with open('DistrictThuDuc_Estimate.json', 'w', encoding='utf-8') as f:
        json.dump(result, f, ensure_ascii=False)
else:
    print('Cannot connected to website')

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import json


url='https://mogi.vn/gia-nha-dat-huyen-binh-chanh-qd358'


# Đường dẫn đến trình điều khiển ChromeDriver
webdriver_service = Service('path/to/chromedriver')

# Khởi tạo trình điều khiển Chrome
driver = webdriver.Chrome(service=webdriver_service)

# Mở trang web
driver.get(url)

driver.implicitly_wait(10)

html_content = driver.page_source

try:
    soup = BeautifulSoup(html_content, 'html.parser')
    type_elements = [i.text for i in soup.find_all('div', class_='mt-street')]
    price_elements = [i.text for i in soup.find_all('div', class_='mt-vol text-right number')]
except:
    print('Cannot connect to website:' + url)

driver.quit()

type = []
price = []
result = []
if type_elements is not None:
    
    for i in range(len(price_elements)):
        price.append(price_elements[i].replace('\n', ' ').strip())
            
    
    for i in range(len(type_elements)):
        type.append(type_elements[i].replace('\n', ' ').replace('\t', ' ').strip())
    
    type = [x for x in type if x not in ["Loại", "Đường"]]
    
    for i in range(len(type)):
        item = {
            'Type Property': type[i],
            'Value Property': price[i]
        }
        result.append(item)

    with open('DistrictBinhChanh_Estimate.json', 'w', encoding='utf-8') as f:
        json.dump(result, f, ensure_ascii=False)
else:
    print('Cannot connected to website')

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import json


url='https://mogi.vn/gia-nha-dat-huyen-can-gio-qd359'


# Đường dẫn đến trình điều khiển ChromeDriver
webdriver_service = Service('path/to/chromedriver')

# Khởi tạo trình điều khiển Chrome
driver = webdriver.Chrome(service=webdriver_service)

# Mở trang web
driver.get(url)

driver.implicitly_wait(10)

html_content = driver.page_source

try:
    soup = BeautifulSoup(html_content, 'html.parser')
    type_elements = [i.text for i in soup.find_all('div', class_='mt-street')]
    price_elements = [i.text for i in soup.find_all('div', class_='mt-vol text-right number')]
except:
    print('Cannot connect to website:' + url)

driver.quit()

type = []
price = []
result = []
if type_elements is not None:
    
    for i in range(len(price_elements)):
        price.append(price_elements[i].replace('\n', ' ').strip())
            
    
    for i in range(len(type_elements)):
        type.append(type_elements[i].replace('\n', ' ').replace('\t', ' ').strip())
    
    type = [x for x in type if x not in ["Loại", "Đường"]]
    
    for i in range(len(type)):
        item = {
            'Type Property': type[i],
            'Value Property': price[i]
        }
        result.append(item)

    with open('DistrictCanGio_Estimate.json', 'w', encoding='utf-8') as f:
        json.dump(result, f, ensure_ascii=False)
else:
    print('Cannot connected to website')

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import json


url='https://mogi.vn/gia-nha-dat-huyen-cu-chi-qd360'


# Đường dẫn đến trình điều khiển ChromeDriver
webdriver_service = Service('path/to/chromedriver')

# Khởi tạo trình điều khiển Chrome
driver = webdriver.Chrome(service=webdriver_service)

# Mở trang web
driver.get(url)

driver.implicitly_wait(10)

html_content = driver.page_source

try:
    soup = BeautifulSoup(html_content, 'html.parser')
    type_elements = [i.text for i in soup.find_all('div', class_='mt-street')]
    price_elements = [i.text for i in soup.find_all('div', class_='mt-vol text-right number')]
except:
    print('Cannot connect to website:' + url)

driver.quit()

type = []
price = []
result = []
if type_elements is not None:
    
    for i in range(len(price_elements)):
        price.append(price_elements[i].replace('\n', ' ').strip())
            
    
    for i in range(len(type_elements)):
        type.append(type_elements[i].replace('\n', ' ').replace('\t', ' ').strip())
    
    type = [x for x in type if x not in ["Loại", "Đường"]]
    
    for i in range(len(type)):
        item = {
            'Type Property': type[i],
            'Value Property': price[i]
        }
        result.append(item)

    with open('DistrictCuChi_Estimate.json', 'w', encoding='utf-8') as f:
        json.dump(result, f, ensure_ascii=False)
else:
    print('Cannot connected to website')

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import json


url='https://mogi.vn/gia-nha-dat-huyen-hoc-mon-qd361'


# Đường dẫn đến trình điều khiển ChromeDriver
webdriver_service = Service('path/to/chromedriver')

# Khởi tạo trình điều khiển Chrome
driver = webdriver.Chrome(service=webdriver_service)

# Mở trang web
driver.get(url)

driver.implicitly_wait(10)

html_content = driver.page_source

try:
    soup = BeautifulSoup(html_content, 'html.parser')
    type_elements = [i.text for i in soup.find_all('div', class_='mt-street')]
    price_elements = [i.text for i in soup.find_all('div', class_='mt-vol text-right number')]
except:
    print('Cannot connect to website:' + url)

driver.quit()

type = []
price = []
result = []
if type_elements is not None:
    
    for i in range(len(price_elements)):
        price.append(price_elements[i].replace('\n', ' ').strip())
            
    
    for i in range(len(type_elements)):
        type.append(type_elements[i].replace('\n', ' ').replace('\t', ' ').strip())
    
    type = [x for x in type if x not in ["Loại", "Đường"]]
    
    for i in range(len(type)):
        item = {
            'Type Property': type[i],
            'Value Property': price[i]
        }
        result.append(item)

    with open('DistrictHoocMon_Estimate.json', 'w', encoding='utf-8') as f:
        json.dump(result, f, ensure_ascii=False)
else:
    print('Cannot connected to website')

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import json


url='https://mogi.vn/gia-nha-dat-huyen-nha-be-qd362'


# Đường dẫn đến trình điều khiển ChromeDriver
webdriver_service = Service('path/to/chromedriver')

# Khởi tạo trình điều khiển Chrome
driver = webdriver.Chrome(service=webdriver_service)

# Mở trang web
driver.get(url)

driver.implicitly_wait(10)

html_content = driver.page_source

try:
    soup = BeautifulSoup(html_content, 'html.parser')
    type_elements = [i.text for i in soup.find_all('div', class_='mt-street')]
    price_elements = [i.text for i in soup.find_all('div', class_='mt-vol text-right number')]
except:
    print('Cannot connect to website:' + url)

driver.quit()

type = []
price = []
result = []
if type_elements is not None:
    
    for i in range(len(price_elements)):
        price.append(price_elements[i].replace('\n', ' ').strip())
            
    
    for i in range(len(type_elements)):
        type.append(type_elements[i].replace('\n', ' ').replace('\t', ' ').strip())
    
    type = [x for x in type if x not in ["Loại", "Đường"]]
    
    for i in range(len(type)):
        item = {
            'Type Property': type[i],
            'Value Property': price[i]
        }
        result.append(item)

    with open('DistrictNhaBe_Estimate.json', 'w', encoding='utf-8') as f:
        json.dump(result, f, ensure_ascii=False)
else:
    print('Cannot connected to website')
